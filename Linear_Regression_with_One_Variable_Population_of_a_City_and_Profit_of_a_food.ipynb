# %% [markdown]
# # Linear Regression with One Variable

# %% [markdown]
# Linear Regression with One Variable
# First some context on the problem statement. Here we will implement linear regression with one variable to predict profits for a food truck. Suppose you are the CEO of a restaurant franchise and are considering different cities for opening a new outlet. The chain already has trucks in various cities and you have data for profits and populations from the cities. The file ex1data1.txt contains the dataset for our linear regression exercise. `The first column is the population of a city` and `the second column is the profit of a food truck in that city`. A negative value for profit indicates a loss.
#
# First, as with doing any machine learning task, we need to import certain libraries.

# %% [markdown]
# **Step 1.** Import certain libraries:

# %%
#import certain libraries numpy, pandas, and matplotlib.pyplot import seaborn as sns

# %% [markdown]
# Step 2. Read the data and create matrices:

# %% [markdown]
# Reading and Plotting the data
# Before starting on any task, it is often useful to understand the data by visualizing it. For this dataset, you can use a scatter plot to visualize the data, since it has only two properties to plot (profit and population).

# %%
#Read the dataset 'ex1data1.txt'


# read first column Population of City in 10,000s


# read second column the profit of a food truck in that city


# number of training examples Profit in $10,000s 


# view first few rows of the data using head()

# %%
# view describe()

# %%
#print all information

# %% [markdown]
# ### Visualising the dataset
# * plot using scatter plotting

# %%
#plot the dataset uisng scatter plotting #plt.scatter(X,y) and label X = Population of City and y = profit

# %%
# Create a rank 1 array
a = np.array([1, 2, 3])   # Create a rank 1 array
print(type(a))            # Prints "<class 'numpy.ndarray'>"
print(a.shape)            # Prints "(3,)"
# Out:
# <class 'numpy.ndarray'>
# (3,)

# %%
b = np.array([[1,2,3],[4,5,6]])    # Create a rank 2 array
print(b.shape)                     # Prints "(2, 3)"
# Out:
# (2, 3)

# %% [markdown]
# `Note` <br>
# **On np.newaxis:** When you read data into `X, y `you will observe that `X, y `are `rank 1` arrays.
# * rank 1 array will have a shape of (m, ) where as rank 2 arrays will have a shape of (m,1). When operating on arrays its good to convert rank 1 arrays to rank 2 arrays because rank 1 arrays often give unexpected results. <br>
# To convert rank 1 to rank 2 array we use `someArray[:,np.newaxis]`.

# %%
#create X and y in rank 2 arrays


#create theta zero and theta one to initialize fitting parameters


#assign iteration number


#learning reate



# adding the intercept term of hstack
ones = np.ones((m,1))
# adding the intercept term of hstack
X = np.hstack((ones,X))

# %% [markdown]
# Next we will be computing the cost and the gradient descent.

# %% [markdown]
# ### Computing the cost
#
# <br>
# Now, given a training set, `how do we pick, or learn, the parameters θ? ` <br>
# One reasonable method seems to be to **make h(x) close to y** at least for the training examples we have. <br>
# To formalize this, we will define a function that measures, for each value of the θ’s, `how close the h(x(i))’s are to the corresponding y (i) ’s. ` We define the **cost function:**  <br>
#
# ![image.png](attachment:image.png)

# %%
# To compute the cost function we need X, y and theta
#Create a function to compute computeCost(X, y, theta)

#creat temp variable that hold the value of np.dot(theta,X)-y


#return the value of np.sum(np.power(temp,2))/2*m
   
    
#Computer J


#You should expect to see a cost of 32.07.

# %% [markdown]
# You should expect to see a cost of 32.07.<br>
# 32.072733877455676

# %% [markdown]
# Finding the optimal parameters using Gradient Descent

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#Create a GradientDescent function (X, y, theta, alpha, iterations)


#user for loop to computer the theta value by assign range(iterations)
   

#compute temp by np.dot(X, theta)- y
    
    
#Computer temp by np.dot(X.T, temp)

        
#update theta value theta = theta - (alpha/m) * temp
       

#return theta value
        
        
#find theta value by calling gradient descent function gradientDescent(X, y, theta, alpha, iterations)


#print the expected theta value[theta0, theta1]
# Out:
# [[0.05839135]
#  [0.6532885 ]]

# %% [markdown]
# Expected theta values [-3.6303, 1.1664]
# We now have the optimized value of theta . Use this value in the above cost function.

# %%
#We now have the optimized value of theta . Use this value in the above cost function.
# Computer J value J = computeCost(X, y, theta)
# Out:
# 6.737190464870006

# %% [markdown]
# It should give you a value of 4.483 which is much better than 32.07

# %% [markdown]
# ### Plot showing the best fit line

# %%
#plot X[:,1], and y using scatter plotting


#label X axis "Population of city in 10,000s"


#label Y axis "Profit in $10,000s"


#plot the model line by plot(X[:,1 ], np.dot(X,theta))
